# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
myarray = np.array([[1,2,3],[4,5,6]])
rownames = ['a','b']
colnames=['f1','f2','f3']
mydataframe = pd.DataFrame(myarray, index = rownames, columns=colnames)
mydataframe
# Out:
#    f1  f2  f3
# a   1   2   3
# b   4   5   6

# %%
myarray = np.array([['a','sandhya',9.6],[4,'shreya',6.5]])
rownames = ['r1','r2']
colnames=['f1','f2','f3']
mydataframe = pd.DataFrame(myarray, index = rownames, columns=colnames)
mydataframe
# Out:
#    f1       f2   f3
# r1  a  sandhya  9.6
# r2  4   shreya  6.5

# %%
path = 'diabetes_dataset.csv'
df = pd.read_csv(path)
df.head()
# Out:
#    Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 0            6      148             72             35        0  33.6
# 1            1       85             66             29        0  26.6
# 2            8      183             64              0        0  23.3
# 3            1       89             66             23       94  28.1
# 4            0      137             40             35      168  43.1
#
#    DiabetesPedigreeFunction  Age  Outcome
# 0                     0.627   50        1
# 1                     0.351   31        0
# 2                     0.672   32        1
# 3                     0.167   21        0
# 4                     2.288   33        1

# %%
colnames = df.columns
colnames
# Out:
# Index(['Pregnancies', 'Glucose', 'BloodPressure', 'SkinThickness', 'Insulin',
#        'BMI', 'DiabetesPedigreeFunction', 'Age', 'Outcome'],
#       dtype='object')

# %%
desc = df.describe()
desc
# Out:
#        Pregnancies     Glucose  BloodPressure  SkinThickness     Insulin  \
# count   768.000000  768.000000     768.000000     768.000000  768.000000
# mean      3.845052  120.894531      69.105469      20.536458   79.799479
# std       3.369578   31.972618      19.355807      15.952218  115.244002
# min       0.000000    0.000000       0.000000       0.000000    0.000000
# 25%       1.000000   99.000000      62.000000       0.000000    0.000000
# 50%       3.000000  117.000000      72.000000      23.000000   30.500000
# 75%       6.000000  140.250000      80.000000      32.000000  127.250000
# max      17.000000  199.000000     122.000000      99.000000  846.000000
#
#               BMI  DiabetesPedigreeFunction         Age     Outcome
# count  768.000000                768.000000  768.000000  768.000000
# mean    31.992578                  0.471876   33.240885    0.348958
# std      7.884160                  0.331329   11.760232    0.476951
# ...

# %%
df.shape
# Out:
# (768, 9)

# %%
df.head(4)
# Out:
#    Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 0            6      148             72             35        0  33.6
# 1            1       85             66             29        0  26.6
# 2            8      183             64              0        0  23.3
# 3            1       89             66             23       94  28.1
#
#    DiabetesPedigreeFunction  Age  Outcome
# 0                     0.627   50        1
# 1                     0.351   31        0
# 2                     0.672   32        1
# 3                     0.167   21        0

# %%
df.groupby('Outcome').size()
# Out:
# Outcome
# 0    500
# 1    268
# dtype: int64

# %%
from pandas.plotting import scatter_matrix
scatter_matrix(df[['Pregnancies','Glucose']])
plt.show()

# %%
#scatter plot
scatter_matrix(df)
plt.show()

# %%
#histogram
df.hist() 
plt.show()

# %%
from sklearn.preprocessing import StandardScaler

#convert data frame to array
arr=df.values                     
#split columns
X=arr[:,0:8]                         
Y=arr[:,8]         

scaler=StandardScaler().fit(X)              #fit data for standardization
rescaledX=scaler.transform(X)             #convert the data as per (x-µ)/σ

np.set_printoptions(precision=3)
print(rescaledX[0:2,:])
print(X[0:2,:])
# Out:
# [[ 0.64   0.848  0.15   0.907 -0.693  0.204  0.468  1.426]
#  [-0.845 -1.123 -0.161  0.531 -0.693 -0.684 -0.365 -0.191]]
# [[  6.    148.     72.     35.      0.     33.6     0.627  50.   ]
#  [  1.     85.     66.     29.      0.     26.6     0.351  31.   ]]

# %%
myarray=np.array([1,3,-10,4,5,7,-4,-2,10])
mydataframe = pd.DataFrame(myarray)
print(mydataframe)
mydataframe.plot(kind='bar')
plt.show()
# Out:
#     0
# 0   1
# 1   3
# 2 -10
# 3   4
# 4   5
# 5   7
# 6  -4
# 7  -2
# 8  10

# %%
from sklearn import preprocessing

fl_x=mydataframe.values.astype(float)

#fl_x=mydataframe[['f1']].values.astype(float)   #If specific feature name is to be converted 

min_max_scaler=preprocessing.MinMaxScaler()
X_scaled=min_max_scaler.fit_transform(fl_x)
df_normalized=pd.DataFrame(X_scaled)
print(df_normalized)
df_normalized.plot(kind='bar')
plt.show()
# Out:
#       0
# 0  0.55
# 1  0.65
# 2  0.00
# 3  0.70
# 4  0.75
# 5  0.85
# 6  0.30
# 7  0.40
# 8  1.00

# %%
#Question 1,2 : Read csv and put it into a dataframe
path_cancer = 'cancer_dataset.csv'
canc_df = pd.read_csv(path_cancer)
canc_df.shape
# Out:
# (569, 32)

# %%
col_cancer = canc_df.columns
col_cancer
# Out:
# Index(['id', 'diagnosis', 'radius_mean', 'texture_mean', 'perimeter_mean',
#        'area_mean', 'smoothness_mean', 'compactness_mean', 'concavity_mean',
#        'concave points_mean', 'symmetry_mean', 'fractal_dimension_mean',
#        'radius_se', 'texture_se', 'perimeter_se', 'area_se', 'smoothness_se',
#        'compactness_se', 'concavity_se', 'concave points_se', 'symmetry_se',
#        'fractal_dimension_se', 'radius_worst', 'texture_worst',
#        'perimeter_worst', 'area_worst', 'smoothness_worst',
#        'compactness_worst', 'concavity_worst', 'concave points_worst',
#        'symmetry_worst', 'fractal_dimension_worst'],
#       dtype='object')

# %%
#Question 3: Statistical data
#a) Description
desc_cancer = canc_df.describe()
desc_cancer
# Out:
#                  id  radius_mean  texture_mean  perimeter_mean    area_mean  \
# count  5.690000e+02   569.000000    569.000000      569.000000   569.000000
# mean   3.037183e+07    14.127292     19.289649       91.969033   654.889104
# std    1.250206e+08     3.524049      4.301036       24.298981   351.914129
# min    8.670000e+03     6.981000      9.710000       43.790000   143.500000
# 25%    8.692180e+05    11.700000     16.170000       75.170000   420.300000
# 50%    9.060240e+05    13.370000     18.840000       86.240000   551.100000
# 75%    8.813129e+06    15.780000     21.800000      104.100000   782.700000
# max    9.113205e+08    28.110000     39.280000      188.500000  2501.000000
#
#        smoothness_mean  compactness_mean  concavity_mean  concave points_mean  \
# count       569.000000        569.000000      569.000000           569.000000
# mean          0.096360          0.104341        0.088799             0.048919
# ...

# %%
#b) Size of matrix
canc_df.shape
# Out:
# (569, 32)

# %%
#c) Peek data
canc_df.head(10)
# Out:
#          id diagnosis  radius_mean  texture_mean  perimeter_mean  area_mean  \
# 0    842302         M        17.99         10.38          122.80     1001.0
# 1    842517         M        20.57         17.77          132.90     1326.0
# 2  84300903         M        19.69         21.25          130.00     1203.0
# 3  84348301         M        11.42         20.38           77.58      386.1
# 4  84358402         M        20.29         14.34          135.10     1297.0
# 5    843786         M        12.45         15.70           82.57      477.1
# 6    844359         M        18.25         19.98          119.60     1040.0
# 7  84458202         M        13.71         20.83           90.20      577.9
# 8    844981         M        13.00         21.82           87.50      519.8
# 9  84501001         M        12.46         24.04           83.97      475.9
#
#    smoothness_mean  compactness_mean  concavity_mean  concave points_mean  \
# ...

# %%
canc_df.groupby('diagnosis').size()
# Out:
# diagnosis
# B    357
# M    212
# dtype: int64

# %%
#Question 4:Data visualization
scatter_matrix(canc_df[['perimeter_mean','area_mean']])
plt.show()

# %%
scatter_matrix(canc_df[0:3])
plt.show()

# %%
#Question 5: Standardize data
from sklearn.preprocessing import StandardScaler

arr=canc_df.values                     #convert data frame to array
X=arr[:,2:32]                         #split columns
Y=arr[:,1]                       
scaler=StandardScaler().fit(X)              #fit data for standardization
rescaledX=scaler.transform(X)             #convert the data as per (x-µ)/σ

np.set_printoptions(precision=3)
print(rescaledX[0:2,:])
print(X[0:2,:])
# Out:
# [[ 1.097e+00 -2.073e+00  1.270e+00  9.844e-01  1.568e+00  3.284e+00
#    2.653e+00  2.532e+00  2.218e+00  2.256e+00  2.490e+00 -5.653e-01
#    2.833e+00  2.488e+00 -2.140e-01  1.317e+00  7.240e-01  6.608e-01
#    1.149e+00  9.071e-01  1.887e+00 -1.359e+00  2.304e+00  2.001e+00
#    1.308e+00  2.617e+00  2.110e+00  2.296e+00  2.751e+00  1.937e+00]
#  [ 1.830e+00 -3.536e-01  1.686e+00  1.909e+00 -8.270e-01 -4.871e-01
#   -2.385e-02  5.481e-01  1.392e-03 -8.687e-01  4.993e-01 -8.762e-01
#    2.633e-01  7.424e-01 -6.054e-01 -6.929e-01 -4.408e-01  2.602e-01
#   -8.055e-01 -9.944e-02  1.806e+00 -3.692e-01  1.535e+00  1.890e+00
#   -3.756e-01 -4.304e-01 -1.467e-01  1.087e+00 -2.439e-01  2.812e-01]]
# [[17.99 10.38 122.8 1001.0 0.1184 0.2776 0.3001 0.1471 0.2419 0.07871
#   1.095 0.9053 8.589 153.4 0.006399 0.04904 0.05372999999999999 0.01587
#   0.03003 0.006193 25.38 17.33 184.6 2019.0 0.1622 0.6656 0.7119 0.2654
#   0.4601 0.1189]
# ...

# %%
#Question 6: Normalise data 
canc_df[0:2].plot(kind='bar')
plt.show()

# %%
canc_df.replace('M',1,inplace=True)
canc_df.replace('B',0,inplace=True)
canc_df.diagnosis.astype(float)
canc_df.drop(columns=['id'],inplace=True)
canc_df.head()
# Out:
#    diagnosis  radius_mean  texture_mean  perimeter_mean  area_mean  \
# 0          1        17.99         10.38          122.80     1001.0
# 1          1        20.57         17.77          132.90     1326.0
# 2          1        19.69         21.25          130.00     1203.0
# 3          1        11.42         20.38           77.58      386.1
# 4          1        20.29         14.34          135.10     1297.0
#
#    smoothness_mean  compactness_mean  concavity_mean  concave points_mean  \
# 0          0.11840           0.27760          0.3001              0.14710
# 1          0.08474           0.07864          0.0869              0.07017
# 2          0.10960           0.15990          0.1974              0.12790
# 3          0.14250           0.28390          0.2414              0.10520
# 4          0.10030           0.13280          0.1980              0.10430
#
#    symmetry_mean  ...  radius_worst  texture_worst  perimeter_worst  \
# ...

# %%
from sklearn import preprocessing

fl_x=canc_df.values.astype(float)

#fl_x=mydataframe[['f1']].values.astype(float)   #If specific feature name is to be converted 

min_max_scaler=preprocessing.MinMaxScaler()
X_scaled=min_max_scaler.fit_transform(fl_x)
df_normalized=pd.DataFrame(X_scaled)
df_normalized
# Out:
#       0         1         2         3         4         5         6   \
# 0    1.0  0.521037  0.022658  0.545989  0.363733  0.593753  0.792037
# 1    1.0  0.643144  0.272574  0.615783  0.501591  0.289880  0.181768
# 2    1.0  0.601496  0.390260  0.595743  0.449417  0.514309  0.431017
# 3    1.0  0.210090  0.360839  0.233501  0.102906  0.811321  0.811361
# 4    1.0  0.629893  0.156578  0.630986  0.489290  0.430351  0.347893
# ..   ...       ...       ...       ...       ...       ...       ...
# 564  1.0  0.690000  0.428813  0.678668  0.566490  0.526948  0.296055
# 565  1.0  0.622320  0.626987  0.604036  0.474019  0.407782  0.257714
# 566  1.0  0.455251  0.621238  0.445788  0.303118  0.288165  0.254340
# 567  1.0  0.644564  0.663510  0.665538  0.475716  0.588336  0.790197
# 568  0.0  0.036869  0.501522  0.028540  0.015907  0.000000  0.074351
#
#            7         8         9   ...        21        22        23  \
# ...

# %%
df_normalized.plot(kind='bar')
plt.show()

# %%
import seaborn as sns
corr = canc_df.corr()
sns.heatmap(corr)
plt.title("Correlation Matrix")
plt.show()

# %%
threshold = 0.50
filtermat = np.abs(corr["diagnosis"]) > threshold
corr_features = corr.columns[filtermat].tolist()
sns.clustermap(canc_df[corr_features].corr(),annot=True,fmt=".2f",figsize=(12,8));
plt.title("Correlation >50%");
plt.show();
